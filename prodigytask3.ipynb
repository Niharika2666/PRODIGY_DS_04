# %%
import pandas as pd
import numpy as nu
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('twitter_training.csv')

# %%
data.head(30)
# Out:
#     2401  Borderlands  Positive  \
# 0   2401  Borderlands  Positive
# 1   2401  Borderlands  Positive
# 2   2401  Borderlands  Positive
# 3   2401  Borderlands  Positive
# 4   2401  Borderlands  Positive
# 5   2402  Borderlands  Positive
# 6   2402  Borderlands  Positive
# 7   2402  Borderlands  Positive
# 8   2402  Borderlands  Positive
# 9   2402  Borderlands  Positive
# 10  2402  Borderlands  Positive
# 11  2403  Borderlands   Neutral
# 12  2403  Borderlands   Neutral
# 13  2403  Borderlands   Neutral
# 14  2403  Borderlands   Neutral
# 15  2403  Borderlands   Neutral
# 16  2403  Borderlands   Neutral
# 17  2404  Borderlands  Positive
# 18  2404  Borderlands  Positive
# 19  2404  Borderlands  Positive
# 20  2404  Borderlands  Positive
# 21  2404  Borderlands  Positive
# 22  2404  Borderlands  Positive
# 23  2405  Borderlands  Negative
# 24  2405  Borderlands  Negative
# 25  2405  Borderlands  Negative
# 26  2405  Borderlands  Negative
# 27  2405  Borderlands  Negative
# ...

# %%
data.rename(columns={
    '2401': 'new_column_name1',
    'Borderlands': 'new_column_name2',
    'Positive': 'response',
    'im getting on borderlands and i will murder you all ,':'msg'
    # Add more as needed
}, inplace=True)

# Save the updated DataFrame back to CSV
data.to_csv('your_file.csv', index=False)

# %%
data.head()
# Out:
#    new_column_name1 new_column_name2  response  \
# 0              2401      Borderlands  Positive
# 1              2401      Borderlands  Positive
# 2              2401      Borderlands  Positive
# 3              2401      Borderlands  Positive
# 4              2401      Borderlands  Positive
#
#                                                  msg
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
data[ data['response']=='Positive'].count()
# Out:
# new_column_name1    20831
# new_column_name2    20831
# response            20831
# msg                 20654
# dtype: int64

# %%
data[ data['response']=='Negative'].count()
# Out:
# new_column_name1    22542
# new_column_name2    22542
# response            22542
# msg                 22358
# dtype: int64

# %%
data[ data['response']=='Neutral'].count()
# Out:
# new_column_name1    18318
# new_column_name2    18318
# response            18318
# msg                 18108
# dtype: int64

# %%
data.count()
# Out:
# new_column_name1    74681
# new_column_name2    74681
# response            74681
# msg                 73995
# dtype: int64

# %%
plt.hist(data['response'],bins=4,edgecolor='black')
# Out:
# (array([20831., 18318., 22542., 12990.]),
#  array([0.  , 0.75, 1.5 , 2.25, 3.  ]),
#  <BarContainer object of 4 artists>)

# %%
plt.hist(data['new_column_name2'],bins=32,edgecolor='black',orientation='horizontal')
# Out:
# (array([2285., 2376., 2316., 2334., 2334., 2352., 2364., 2310., 2364.,
#         2304., 2298., 2244., 2376., 2394., 2274., 2400., 2298., 2346.,
#         2274., 2382., 2310., 2340., 2262., 2394., 2400., 2370., 2304.,
#         2400., 2328., 2304., 2346., 2298.]),
#  array([ 0.     ,  0.96875,  1.9375 ,  2.90625,  3.875  ,  4.84375,
#          5.8125 ,  6.78125,  7.75   ,  8.71875,  9.6875 , 10.65625,
#         11.625  , 12.59375, 13.5625 , 14.53125, 15.5    , 16.46875,
#         17.4375 , 18.40625, 19.375  , 20.34375, 21.3125 , 22.28125,
#         23.25   , 24.21875, 25.1875 , 26.15625, 27.125  , 28.09375,
#         29.0625 , 30.03125, 31.     ]),
#  <BarContainer object of 32 artists>)

# %%
data1=pd.read_csv('twitter_validation.csv')

# %%
data1.head()
# Out:
#    3364   Facebook Irrelevant  \
# 0   352     Amazon    Neutral
# 1  8312  Microsoft   Negative
# 2  4371      CS-GO   Negative
# 3  4433     Google    Neutral
# 4  6273       FIFA   Negative
#
#   I mentioned on Facebook that I was struggling for motivation to go for a run the other day, which has been translated by Tom’s great auntie as ‘Hayley can’t get out of bed’ and told to his grandma, who now thinks I’m a lazy, terrible person 🤣
# 0  BBC News - Amazon boss Jeff Bezos rejects clai...
# 1  @Microsoft Why do I pay for WORD when it funct...
# 2  CSGO matchmaking is so full of closet hacking,...
# 3  Now the President is slapping Americans in the...
# 4  Hi @EAHelp I’ve had Madeleine McCann in my cel...

# %%
data1.rename(columns={
    '3364': 'new_column_name1',
    'Facebook': 'new_column_name2',
    'Irrelevant': 'response',
    'I mentioned on Facebook that I was struggling for motivation to go for a run the other day, which has been translated by Tom’s great auntie as ‘Hayley can’t get out of bed’ and told to his grandma, who now thinks I’m a lazy, terrible person 🤣':'msg'
    # Add more as needed
}, inplace=True)

# Save the updated DataFrame back to CSV
data1.to_csv('your_file.csv', index=False)

# %%
data1.head()
# Out:
#    new_column_name1 new_column_name2  response  \
# 0               352           Amazon   Neutral
# 1              8312        Microsoft  Negative
# 2              4371            CS-GO  Negative
# 3              4433           Google   Neutral
# 4              6273             FIFA  Negative
#
#                                                  msg
# 0  BBC News - Amazon boss Jeff Bezos rejects clai...
# 1  @Microsoft Why do I pay for WORD when it funct...
# 2  CSGO matchmaking is so full of closet hacking,...
# 3  Now the President is slapping Americans in the...
# 4  Hi @EAHelp I’ve had Madeleine McCann in my cel...

# %%
plt.hist(data1['response'],bins=4,edgecolor='black')
# Out:
# (array([285., 266., 277., 171.]),
#  array([0.  , 0.75, 1.5 , 2.25, 3.  ]),
#  <BarContainer object of 4 artists>)

# %%
plt.hist(data1['new_column_name2'],bins=32,edgecolor='black',orientation='horizontal')
# Out:
# (array([34., 28., 32., 24., 38., 29., 35., 33., 31., 27., 32., 21., 35.,
#         35., 40., 32., 36., 32., 38., 33., 33., 39., 34., 26., 27., 32.,
#         18., 30., 22., 30., 37., 26.]),
#  array([ 0.     ,  0.96875,  1.9375 ,  2.90625,  3.875  ,  4.84375,
#          5.8125 ,  6.78125,  7.75   ,  8.71875,  9.6875 , 10.65625,
#         11.625  , 12.59375, 13.5625 , 14.53125, 15.5    , 16.46875,
#         17.4375 , 18.40625, 19.375  , 20.34375, 21.3125 , 22.28125,
#         23.25   , 24.21875, 25.1875 , 26.15625, 27.125  , 28.09375,
#         29.0625 , 30.03125, 31.     ]),
#  <BarContainer object of 32 artists>)
